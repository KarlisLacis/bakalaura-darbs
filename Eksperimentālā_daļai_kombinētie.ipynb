# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
import warnings
import pandas as pd
import numpy as np
import datetime
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold
from keras.preprocessing import text
from keras import models, layers
from imblearn.under_sampling import ClusterCentroids, NearMiss, RandomUnderSampler
from imblearn.over_sampling import SMOTE, SVMSMOTE, BorderlineSMOTE

# %%
warnings.filterwarnings('ignore')
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets'
fasttext_data         = pd.read_csv('2020_05_09_encoded_Fasttext.csv', index_col=0)
base_data             = pd.read_csv('papildinatie_jautajumi_cleaned.csv', index_col=0)
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded'
bert_big_data         = pd.read_csv('2020_05_10_encoded_BERT_big.csv', index_col=0)
bert_multi_cased_data = pd.read_csv('2020_05_10_encoded_BERT_multi_cased.csv', index_col=0)
bert_small_2_data     = pd.read_csv('2020_05_10_encoded_BERT_small_2.csv', index_col=0)
bert_small_data       = pd.read_csv('2020_05_10_encoded_BERT_small.csv', index_col=0)
print('Papildinato jautājumu kopa: ', base_data.shape, 'FastText iekodētā datu kopa:', fasttext_data.shape)
print('BERT 1 dati:', bert_small_data.shape, 'BERT 2 dati:',  bert_small_2_data.shape, 'BERT 3 dati:', bert_multi_cased_data.shape, 'BERT 4 dati:', bert_big_data.shape)
# Out:
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded
# Papildinato jautājumu kopa:  (23391, 2) FastText iekodētā datu kopa: (23391, 301)
# BERT 1 dati: (23391, 257) BERT 2 dati: (23391, 257) BERT 3 dati: (23391, 769) BERT 4 dati: (23391, 769)

# %%
def transformResults(results):            # funkcija, kas pārvērš saņemtus rezultātus, izvēloties populārākās klases indeksu katrā masīva rindā
    mod_results = []
    for result in results:
        out = np.argmax(result)
        mod_results.append(out)
    mod_results = np.array(mod_results)  
    return mod_results

# %%
indices      = range(3)
indices2     = range(3)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5 
results1 = []
header_row = ['Modelis', 'RandomUS_SMOTE', 'NearMiss_SMOTE', 'Cluster_SMOTE', 'RandomUS_BSMOTE', 'NearMiss_BSMOTE', 'Cluster_BSMOTE', 
              'RandomUS_SVMSMOTE', 'NearMiss_SVMSMOTE', 'Cluster_SVMSMOTE']
results1.append(header_row)

# %%
bert_big_data['labels'].value_counts()
# Out:
# 1    23025
# 3      122
# 2      122
# 0      122
# Name: labels, dtype: int64

# %% [markdown]
# <h3>300% OverSampling + UnderSampling uz 122 </h3>

# %%
class_size = round(122 / 5 * 4) # klases izmērs pēc sadalīšanas K-Foldos
size = 4*class_size             # katrai klasei veicam 300% jaunu piemēru izveidošanu
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 392

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print('Reprezentāciju modelis:',model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for k, undersampler in zip( indices2, (RandomUnderSampler(),
                                         NearMiss(),
                                         ClusterCentroids()                                       
                                          )):
    X_res, y_res = undersampler.fit_resample(features, target)                    # Veicam Unersampling
    us_name = undersampler.__class__.__name__
    print('  Pēc', us_name,' UnderSampling, klašu sadalījums:')
    unique, counts = np.unique(y_res, return_counts=True)
    print ('  ', np.asarray((unique, counts)))
    
    for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                         BorderlineSMOTE(sampling_strategy=thisdict),
                                         SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
      os_name = oversampler.__class__.__name__
      print('    ', os_name) 
      model_f1_scores = []
      fold_counter = 0
      for train_index,test_index in StratifiedKFold(n_split).split(X_res, y_res):     # 5-Fold validācija   
        x_train, x_test  = X_res[train_index], X_res[test_index]                      # Izveidojam jautājumu kopas sadalījumu
        y_train, y_test  = y_res[train_index], y_res[test_index]                      # Izveidojam kategorijas kopas sadalījumu
        
        X_res2, y_res2 = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

        model = models.Sequential()                                                   # Izveidojam Neironu tīkla modeli
        model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(4, activation='softmax'))
        model.compile(loss=['sparse_categorical_crossentropy'],
                      optimizer='adam',
                      metrics=['sparse_categorical_accuracy'])
        history = model.fit(X_res2, y_res2,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                            batch_size=batch_size,epochs=epochs,verbose=0)
        y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
        y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

        model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
        model_f1_scores.append(model_f1_avg)
        fold_counter = fold_counter + 1
        print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
  
      model_f1 = round(np.mean(model_f1_scores), 4)
      result_row.append(model_f1)
      print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all three OverSamplers and all three UnderSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_23_mixed_Under/OverSampling_results_300.csv')
result_data
# Out:
# Reprezentāciju modelis: BERT small #2
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7731
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7668
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7511
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7376
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6553
# 	Completed for: BERT small #2  with F1 score: 0.7368
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7747
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7858
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7431
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7467
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6944
# 	Completed for: BERT small #2  with F1 score: 0.7489
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.766
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7341
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7247
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6992
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6751
# 	Completed for: BERT small #2  with F1 score: 0.7198
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5953
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8378
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8257
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.847
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7638
# 	Completed for: BERT small #2  with F1 score: 0.7739
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5473
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7434
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.792
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8258
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7792
# 	Completed for: BERT small #2  with F1 score: 0.7375
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5078
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7423
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8225
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8121
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8588
# 	Completed for: BERT small #2  with F1 score: 0.7487
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8365
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8468
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7411
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8438
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7949
# 	Completed for: BERT small #2  with F1 score: 0.8126
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.806
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7612
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.71
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8148
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6927
# 	Completed for: BERT small #2  with F1 score: 0.7569
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8277
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7873
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7672
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7814
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7226
# 	Completed for: BERT small #2  with F1 score: 0.7772
# Completed for  BERT small #2  with results= ['BERT small #2', 0.7368, 0.7489, 0.7198, 0.7739, 0.7375, 0.7487, 0.8126, 0.7569, 0.7772]
# Reprezentāciju modelis: BERT small
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7868
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8359
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8257
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8669
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8442
# 	Completed for: BERT small  with F1 score: 0.8319
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8025
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8368
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8354
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.856
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.834
# 	Completed for: BERT small  with F1 score: 0.8329
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8033
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8569
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8356
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8666
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7657
# 	Completed for: BERT small  with F1 score: 0.8256
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6101
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.859
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7841
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8854
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8254
# 	Completed for: BERT small  with F1 score: 0.7928
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7081
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8078
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8367
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.854
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8381
# 	Completed for: BERT small  with F1 score: 0.8089
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7325
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8149
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8448
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8657
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8664
# 	Completed for: BERT small  with F1 score: 0.8249
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.9087
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.9079
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.877
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8882
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8855
# 	Completed for: BERT small  with F1 score: 0.8935
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8885
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8773
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8445
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8977
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8669
# 	Completed for: BERT small  with F1 score: 0.875
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8886
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.877
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8878
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8983
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8962
# 	Completed for: BERT small  with F1 score: 0.8896
# Completed for  BERT small  with results= ['BERT small', 0.8319, 0.8329, 0.8256, 0.7928, 0.8089, 0.8249, 0.8935, 0.875, 0.8896]
# Reprezentāciju modelis: BERT multi cased
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7152
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8512
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8625
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7564
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7629
# 	Completed for: BERT multi cased  with F1 score: 0.7896
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.6717
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8284
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8169
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7928
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7699
# 	Completed for: BERT multi cased  with F1 score: 0.7759
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7447
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8702
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.878
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7846
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8119
# 	Completed for: BERT multi cased  with F1 score: 0.8179
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7727
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.9079
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9279
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8765
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8759
# 	Completed for: BERT multi cased  with F1 score: 0.8722
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7655
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8361
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9277
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8348
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8326
# 	Completed for: BERT multi cased  with F1 score: 0.8393
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7864
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8987
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9283
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.9173
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.838
# 	Completed for: BERT multi cased  with F1 score: 0.8737
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.939
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.817
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8978
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8766
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8961
# 	Completed for: BERT multi cased  with F1 score: 0.8853
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.9179
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8361
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.868
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8881
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8232
# 	Completed for: BERT multi cased  with F1 score: 0.8667
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8556
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8345
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8785
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8775
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7883
# 	Completed for: BERT multi cased  with F1 score: 0.8469
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.7896, 0.7759, 0.8179, 0.8722, 0.8393, 0.8737, 0.8853, 0.8667, 0.8469]
# Reprezentāciju modelis: BERT big
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8877
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8655
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9186
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8638
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8249
# 	Completed for: BERT big  with F1 score: 0.8721
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8421
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8691
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.908
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8638
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8344
# 	Completed for: BERT big  with F1 score: 0.8635
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.857
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8489
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8961
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8645
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.845
# 	Completed for: BERT big  with F1 score: 0.8623
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7594
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8177
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8748
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.948
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9378
# 	Completed for: BERT big  with F1 score: 0.8675
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7767
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8354
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8634
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9068
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9382
# 	Completed for: BERT big  with F1 score: 0.8641
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.6961
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8569
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8416
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9075
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9169
# 	Completed for: BERT big  with F1 score: 0.8438
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9387
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9082
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9699
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8746
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.928
# 	Completed for: BERT big  with F1 score: 0.9239
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9588
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8976
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9795
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8961
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9172
# 	Completed for: BERT big  with F1 score: 0.9298
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9396
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9289
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9699
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8868
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8641
# 	Completed for: BERT big  with F1 score: 0.9179
# Completed for  BERT big  with results= ['BERT big', 0.8721, 0.8635, 0.8623, 0.8675, 0.8641, 0.8438, 0.9239, 0.9298, 0.9179]
# Reprezentāciju modelis: FastText
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8458
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.909
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9095
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8651
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8651
# 	Completed for: FastText  with F1 score: 0.8789
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8427
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8674
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9292
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8656
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.874
# 	Completed for: FastText  with F1 score: 0.8758
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8559
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.9187
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.909
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9185
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8767
# 	Completed for: FastText  with F1 score: 0.8958
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8768
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8978
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9692
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9792
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9585
# 	Completed for: FastText  with F1 score: 0.9363
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.817
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.7825
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.6305
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.6367
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8136
# 	Completed for: FastText  with F1 score: 0.7361
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.7294
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8549
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9589
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9687
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9585
# 	Completed for: FastText  with F1 score: 0.8941
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9186
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.9257
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9071
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9589
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8272
# 	Completed for: FastText  with F1 score: 0.9075
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9187
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8848
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8369
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.928
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.732
# 	Completed for: FastText  with F1 score: 0.8601
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8891
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8976
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9694
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.969
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8258
# 	Completed for: FastText  with F1 score: 0.9102
# Completed for  FastText  with results= ['FastText', 0.8789, 0.8758, 0.8958, 0.9363, 0.7361, 0.8941, 0.9075, 0.8601, 0.9102]
# Total time elapsed: 0:18:53.917106
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-eae2c629762c> in <module>()
#      66 # Saglabājam visus rezultātus
#      67 result_data = pd.DataFrame(results1[1:], columns=results1[0])
# ---> 68 result_data.to_csv('2020_05_23_mixed_Under/OverSampling_results_300.csv')
#      69 result_data
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '2020_05_23_mixed_Under/OverSampling_results_300.csv'

# %%
result_data.to_csv('2020_05_23_mixed_Under_OverSampling_results_300.csv')
result_data
# Out:
#             Modelis  RandomUS_SMOTE  ...  NearMiss_SVMSMOTE  Cluster_SVMSMOTE
# 0     BERT small #2          0.7368  ...             0.7569            0.7772
# 1        BERT small          0.8319  ...             0.8750            0.8896
# 2  BERT multi cased          0.7896  ...             0.8667            0.8469
# 3          BERT big          0.8721  ...             0.9298            0.9179
# 4          FastText          0.8789  ...             0.8601            0.9102
#
# [5 rows x 10 columns]

# %% [markdown]
# <h3>200% OverSampling + UnderSampling uz 122 </h3>

# %%
class_size = round(122 / 5 * 4) # klases izmērs pēc sadalīšanas K-Foldos
size = 3*class_size             # katrai klasei veicam 300% jaunu piemēru izveidošanu
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 294

# %%
indices      = range(3)
indices2     = range(3)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5 
results1 = []
header_row = ['Modelis', 'RandomUS_SMOTE', 'NearMiss_SMOTE', 'Cluster_SMOTE', 'RandomUS_BSMOTE', 'NearMiss_BSMOTE', 'Cluster_BSMOTE', 
              'RandomUS_SVMSMOTE', 'NearMiss_SVMSMOTE', 'Cluster_SVMSMOTE']
results1.append(header_row)

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print('Reprezentāciju modelis:',model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for k, undersampler in zip( indices2, (RandomUnderSampler(),
                                         NearMiss(),
                                         ClusterCentroids()                                       
                                          )):
    X_res, y_res = undersampler.fit_resample(features, target)                    # Veicam Unersampling
    us_name = undersampler.__class__.__name__
    print('  Pēc', us_name,' UnderSampling, klašu sadalījums:')
    unique, counts = np.unique(y_res, return_counts=True)
    print ('  ', np.asarray((unique, counts)))
    
    for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                         BorderlineSMOTE(sampling_strategy=thisdict),
                                         SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
      os_name = oversampler.__class__.__name__
      print('    ', os_name) 
      model_f1_scores = []
      fold_counter = 0
      for train_index,test_index in StratifiedKFold(n_split).split(X_res, y_res):     # 5-Fold validācija   
        x_train, x_test  = X_res[train_index], X_res[test_index]                      # Izveidojam jautājumu kopas sadalījumu
        y_train, y_test  = y_res[train_index], y_res[test_index]                      # Izveidojam kategorijas kopas sadalījumu
        
        X_res2, y_res2 = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

        model = models.Sequential()                                                   # Izveidojam Neironu tīkla modeli
        model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(4, activation='softmax'))
        model.compile(loss=['sparse_categorical_crossentropy'],
                      optimizer='adam',
                      metrics=['sparse_categorical_accuracy'])
        history = model.fit(X_res2, y_res2,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                            batch_size=batch_size,epochs=epochs,verbose=0)
        y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
        y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

        model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
        model_f1_scores.append(model_f1_avg)
        fold_counter = fold_counter + 1
        print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
  
      model_f1 = round(np.mean(model_f1_scores), 4)
      result_row.append(model_f1)
      print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all three OverSamplers and all three UnderSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_23_mixed_Under_OverSampling_results_200.csv')
result_data
# Out:
# Reprezentāciju modelis: BERT small #2
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7211
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7319
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6825
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6813
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6692
# 	Completed for: BERT small #2  with F1 score: 0.6972
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7497
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7643
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6906
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7554
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6749
# 	Completed for: BERT small #2  with F1 score: 0.727
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7357
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7174
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6629
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7456
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6146
# 	Completed for: BERT small #2  with F1 score: 0.6952
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5097
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7966
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8261
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7634
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7739
# 	Completed for: BERT small #2  with F1 score: 0.7339
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.6123
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7673
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.79
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.815
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8293
# 	Completed for: BERT small #2  with F1 score: 0.7628
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5244
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.762
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7623
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8168
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8696
# 	Completed for: BERT small #2  with F1 score: 0.747
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7906
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.836
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.837
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7336
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6847
# 	Completed for: BERT small #2  with F1 score: 0.7764
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7046
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7669
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7593
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7812
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6318
# 	Completed for: BERT small #2  with F1 score: 0.7288
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.786
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7953
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8021
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7635
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6309
# 	Completed for: BERT small #2  with F1 score: 0.7556
# Completed for  BERT small #2  with results= ['BERT small #2', 0.6972, 0.727, 0.6952, 0.7339, 0.7628, 0.747, 0.7764, 0.7288, 0.7556]
# Reprezentāciju modelis: BERT small
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8592
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7889
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.838
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8272
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.6951
# 	Completed for: BERT small  with F1 score: 0.8017
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.859
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7918
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8238
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8463
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.744
# 	Completed for: BERT small  with F1 score: 0.813
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8689
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8042
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8247
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8349
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7851
# 	Completed for: BERT small  with F1 score: 0.8236
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7471
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8347
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7819
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8756
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8255
# 	Completed for: BERT small  with F1 score: 0.813
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6822
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8398
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7823
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8323
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8861
# 	Completed for: BERT small  with F1 score: 0.8045
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6949
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8278
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8369
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8649
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.867
# 	Completed for: BERT small  with F1 score: 0.8183
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8674
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8219
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.9081
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8662
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9159
# 	Completed for: BERT small  with F1 score: 0.8759
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.9388
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.856
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8871
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8866
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8329
# 	Completed for: BERT small  with F1 score: 0.8803
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.9182
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8275
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8779
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8596
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9178
# 	Completed for: BERT small  with F1 score: 0.8802
# Completed for  BERT small  with results= ['BERT small', 0.8017, 0.813, 0.8236, 0.813, 0.8045, 0.8183, 0.8759, 0.8803, 0.8802]
# Reprezentāciju modelis: BERT multi cased
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7825
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7961
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8316
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7889
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.856
# 	Completed for: BERT multi cased  with F1 score: 0.811
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7791
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8366
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8771
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7238
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8082
# 	Completed for: BERT multi cased  with F1 score: 0.805
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7665
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8279
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8577
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7807
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8012
# 	Completed for: BERT multi cased  with F1 score: 0.8068
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7571
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.9181
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9396
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8774
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8145
# 	Completed for: BERT multi cased  with F1 score: 0.8613
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8032
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.9069
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9282
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8663
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8568
# 	Completed for: BERT multi cased  with F1 score: 0.8723
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7135
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.9185
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9282
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8662
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8647
# 	Completed for: BERT multi cased  with F1 score: 0.8582
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.9287
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.795
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.888
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.9072
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8833
# 	Completed for: BERT multi cased  with F1 score: 0.8804
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8628
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7867
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8684
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8972
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8623
# 	Completed for: BERT multi cased  with F1 score: 0.8555
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.9198
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.752
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.898
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8966
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8478
# 	Completed for: BERT multi cased  with F1 score: 0.8628
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.811, 0.805, 0.8068, 0.8613, 0.8723, 0.8582, 0.8804, 0.8555, 0.8628]
# Reprezentāciju modelis: BERT big
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9114
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9064
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8075
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8646
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8654
# 	Completed for: BERT big  with F1 score: 0.8711
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8886
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8759
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8043
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8648
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8572
# 	Completed for: BERT big  with F1 score: 0.8582
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.883
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8975
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8367
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9173
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8656
# 	Completed for: BERT big  with F1 score: 0.88
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7189
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8486
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8643
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9485
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9378
# 	Completed for: BERT big  with F1 score: 0.8636
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7749
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.847
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8421
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8971
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.917
# 	Completed for: BERT big  with F1 score: 0.8556
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8388
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8189
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8736
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9379
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9486
# 	Completed for: BERT big  with F1 score: 0.8836
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9172
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.929
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.959
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8844
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8974
# 	Completed for: BERT big  with F1 score: 0.9174
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9177
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9398
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9381
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9054
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9486
# 	Completed for: BERT big  with F1 score: 0.9299
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9181
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9292
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9373
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9159
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.906
# 	Completed for: BERT big  with F1 score: 0.9213
# Completed for  BERT big  with results= ['BERT big', 0.8711, 0.8582, 0.88, 0.8636, 0.8556, 0.8836, 0.9174, 0.9299, 0.9213]
# Reprezentāciju modelis: FastText
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8874
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8664
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8983
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8764
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8948
# 	Completed for: FastText  with F1 score: 0.8847
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8863
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8642
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8995
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8527
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.893
# 	Completed for: FastText  with F1 score: 0.8791
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8657
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8134
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9171
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8543
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.938
# 	Completed for: FastText  with F1 score: 0.8777
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.7928
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8884
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9587
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9794
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9481
# 	Completed for: FastText  with F1 score: 0.9135
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.6503
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5646
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.6212
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.6268
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.647
# 	Completed for: FastText  with F1 score: 0.622
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.7234
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.877
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9591
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9687
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9687
# 	Completed for: FastText  with F1 score: 0.8994
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9073
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8832
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9086
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.907
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8556
# 	Completed for: FastText  with F1 score: 0.8923
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8497
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.9019
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8271
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7862
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7991
# 	Completed for: FastText  with F1 score: 0.8328
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8869
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.9286
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9493
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9281
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8664
# 	Completed for: FastText  with F1 score: 0.9119
# Completed for  FastText  with results= ['FastText', 0.8847, 0.8791, 0.8777, 0.9135, 0.622, 0.8994, 0.8923, 0.8328, 0.9119]
# Total time elapsed: 0:18:55.281933
#             Modelis  RandomUS_SMOTE  ...  NearMiss_SVMSMOTE  Cluster_SVMSMOTE
# 0     BERT small #2          0.6972  ...             0.7288            0.7556
# 1        BERT small          0.8017  ...             0.8803            0.8802
# 2  BERT multi cased          0.8110  ...             0.8555            0.8628
# 3          BERT big          0.8711  ...             0.9299            0.9213
# 4          FastText          0.8847  ...             0.8328            0.9119
#
# [5 rows x 10 columns]

# %% [markdown]
# <h3>100% OverSampling + UnderSampling uz 122 </h3>

# %%
class_size = round(122 / 5 * 4) # klases izmērs pēc sadalīšanas K-Foldos
size = 2*class_size             # katrai klasei veicam 300% jaunu piemēru izveidošanu
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 196

# %%
indices      = range(3)
indices2     = range(3)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5 
results1 = []
header_row = ['Modelis', 'RandomUS_SMOTE', 'NearMiss_SMOTE', 'Cluster_SMOTE', 'RandomUS_BSMOTE', 'NearMiss_BSMOTE', 'Cluster_BSMOTE', 
              'RandomUS_SVMSMOTE', 'NearMiss_SVMSMOTE', 'Cluster_SVMSMOTE']
results1.append(header_row)

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print('Reprezentāciju modelis:',model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for k, undersampler in zip( indices2, (RandomUnderSampler(),
                                         NearMiss(),
                                         ClusterCentroids()                                       
                                          )):
    X_res, y_res = undersampler.fit_resample(features, target)                    # Veicam Unersampling
    us_name = undersampler.__class__.__name__
    print('  Pēc', us_name,' UnderSampling, klašu sadalījums:')
    unique, counts = np.unique(y_res, return_counts=True)
    print ('  ', np.asarray((unique, counts)))
    
    for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                         BorderlineSMOTE(sampling_strategy=thisdict),
                                         SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
      os_name = oversampler.__class__.__name__
      print('    ', os_name) 
      model_f1_scores = []
      fold_counter = 0
      for train_index,test_index in StratifiedKFold(n_split).split(X_res, y_res):     # 5-Fold validācija   
        x_train, x_test  = X_res[train_index], X_res[test_index]                      # Izveidojam jautājumu kopas sadalījumu
        y_train, y_test  = y_res[train_index], y_res[test_index]                      # Izveidojam kategorijas kopas sadalījumu
        
        X_res2, y_res2 = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

        model = models.Sequential()                                                   # Izveidojam Neironu tīkla modeli
        model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(4, activation='softmax'))
        model.compile(loss=['sparse_categorical_crossentropy'],
                      optimizer='adam',
                      metrics=['sparse_categorical_accuracy'])
        history = model.fit(X_res2, y_res2,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                            batch_size=batch_size,epochs=epochs,verbose=0)
        y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
        y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

        model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
        model_f1_scores.append(model_f1_avg)
        fold_counter = fold_counter + 1
        print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
  
      model_f1 = round(np.mean(model_f1_scores), 4)
      result_row.append(model_f1)
      print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all three OverSamplers and all three UnderSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_23_mixed_Under_OverSampling_results_100.csv')
result_data
# Out:
# Reprezentāciju modelis: BERT small #2
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7127
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7211
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7778
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7308
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5649
# 	Completed for: BERT small #2  with F1 score: 0.7015
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.74
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7944
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7546
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6505
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5848
# 	Completed for: BERT small #2  with F1 score: 0.7049
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7108
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.751
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7881
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7547
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5842
# 	Completed for: BERT small #2  with F1 score: 0.7178
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5768
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8073
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8055
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7741
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7091
# 	Completed for: BERT small #2  with F1 score: 0.7346
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.504
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7822
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7712
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8096
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7622
# 	Completed for: BERT small #2  with F1 score: 0.7258
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4515
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7557
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7431
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8329
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7662
# 	Completed for: BERT small #2  with F1 score: 0.7099
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7205
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7127
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8253
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7462
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6849
# 	Completed for: BERT small #2  with F1 score: 0.7379
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7766
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.6757
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6986
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6689
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6352
# 	Completed for: BERT small #2  with F1 score: 0.691
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7854
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.6718
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7443
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7515
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6877
# 	Completed for: BERT small #2  with F1 score: 0.7281
# Completed for  BERT small #2  with results= ['BERT small #2', 0.7015, 0.7049, 0.7178, 0.7346, 0.7258, 0.7099, 0.7379, 0.691, 0.7281]
# Reprezentāciju modelis: BERT small
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8359
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8086
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8438
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7701
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7427
# 	Completed for: BERT small  with F1 score: 0.8002
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7742
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7558
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8373
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7832
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7645
# 	Completed for: BERT small  with F1 score: 0.783
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8258
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7454
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8246
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7757
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7416
# 	Completed for: BERT small  with F1 score: 0.7826
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7213
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8397
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8654
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.9064
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8773
# 	Completed for: BERT small  with F1 score: 0.842
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7704
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8558
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8328
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8661
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8281
# 	Completed for: BERT small  with F1 score: 0.8306
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7045
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8455
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8056
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8967
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8971
# 	Completed for: BERT small  with F1 score: 0.8299
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8681
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.849
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8845
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8866
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8762
# 	Completed for: BERT small  with F1 score: 0.8729
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8533
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8661
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7834
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8862
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8348
# 	Completed for: BERT small  with F1 score: 0.8448
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8705
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8983
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.9058
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8657
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8422
# 	Completed for: BERT small  with F1 score: 0.8765
# Completed for  BERT small  with results= ['BERT small', 0.8002, 0.783, 0.7826, 0.842, 0.8306, 0.8299, 0.8729, 0.8448, 0.8765]
# Reprezentāciju modelis: BERT multi cased
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7734
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7549
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.763
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7744
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7757
# 	Completed for: BERT multi cased  with F1 score: 0.7683
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7869
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8486
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8179
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7085
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7933
# 	Completed for: BERT multi cased  with F1 score: 0.791
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7981
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7864
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.7758
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7499
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7637
# 	Completed for: BERT multi cased  with F1 score: 0.7748
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.755
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8874
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9391
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8301
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8436
# 	Completed for: BERT multi cased  with F1 score: 0.851
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7687
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8573
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9293
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.835
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8132
# 	Completed for: BERT multi cased  with F1 score: 0.8407
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8081
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8863
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9389
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8465
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8347
# 	Completed for: BERT multi cased  with F1 score: 0.8629
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8978
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8372
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9004
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7937
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8015
# 	Completed for: BERT multi cased  with F1 score: 0.8461
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8279
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7761
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8986
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8541
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8339
# 	Completed for: BERT multi cased  with F1 score: 0.8381
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7411
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8355
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8872
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8453
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7987
# 	Completed for: BERT multi cased  with F1 score: 0.8216
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.7683, 0.791, 0.7748, 0.851, 0.8407, 0.8629, 0.8461, 0.8381, 0.8216]
# Reprezentāciju modelis: BERT big
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8437
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8259
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8368
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8125
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8301
# 	Completed for: BERT big  with F1 score: 0.8298
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8631
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.815
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9182
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.845
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8552
# 	Completed for: BERT big  with F1 score: 0.8593
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8559
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8576
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9396
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8481
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8656
# 	Completed for: BERT big  with F1 score: 0.8734
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.6824
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8366
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8431
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9491
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9479
# 	Completed for: BERT big  with F1 score: 0.8518
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8013
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8466
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8634
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8863
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9486
# 	Completed for: BERT big  with F1 score: 0.8692
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7462
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8269
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8831
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9277
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9479
# 	Completed for: BERT big  with F1 score: 0.8664
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9486
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9079
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.959
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.896
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8835
# 	Completed for: BERT big  with F1 score: 0.919
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9377
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9186
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9391
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9067
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9481
# 	Completed for: BERT big  with F1 score: 0.93
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9382
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.929
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9577
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9069
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9267
# 	Completed for: BERT big  with F1 score: 0.9317
# Completed for  BERT big  with results= ['BERT big', 0.8298, 0.8593, 0.8734, 0.8518, 0.8692, 0.8664, 0.919, 0.93, 0.9317]
# Reprezentāciju modelis: FastText
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8166
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.7975
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8997
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8731
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8516
# 	Completed for: FastText  with F1 score: 0.8477
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8532
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8372
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9387
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8838
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8425
# 	Completed for: FastText  with F1 score: 0.8711
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8574
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.826
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9286
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.895
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8408
# 	Completed for: FastText  with F1 score: 0.8696
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.7895
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8779
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9293
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9485
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9585
# 	Completed for: FastText  with F1 score: 0.9007
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.6216
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5566
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.6212
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.6159
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6443
# 	Completed for: FastText  with F1 score: 0.6119
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8677
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8657
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.918
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9483
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9483
# 	Completed for: FastText  with F1 score: 0.9096
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9382
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8643
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9286
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9068
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7828
# 	Completed for: FastText  with F1 score: 0.8841
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8962
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8926
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.827
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8593
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7494
# 	Completed for: FastText  with F1 score: 0.8449
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8884
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8434
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8555
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8842
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7059
# 	Completed for: FastText  with F1 score: 0.8355
# Completed for  FastText  with results= ['FastText', 0.8477, 0.8711, 0.8696, 0.9007, 0.6119, 0.9096, 0.8841, 0.8449, 0.8355]
# Total time elapsed: 0:19:18.022530
#             Modelis  RandomUS_SMOTE  ...  NearMiss_SVMSMOTE  Cluster_SVMSMOTE
# 0     BERT small #2          0.7015  ...             0.6910            0.7281
# 1        BERT small          0.8002  ...             0.8448            0.8765
# 2  BERT multi cased          0.7683  ...             0.8381            0.8216
# 3          BERT big          0.8298  ...             0.9300            0.9317
# 4          FastText          0.8477  ...             0.8449            0.8355
#
# [5 rows x 10 columns]

# %% [markdown]
# <h3>400% OverSampling + UnderSampling uz 122 </h3>

# %%
class_size = round(122 / 5 * 4) # klases izmērs pēc sadalīšanas K-Foldos
size = 5*class_size             # katrai klasei veicam 300% jaunu piemēru izveidošanu
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 490

# %%
indices      = range(3)
indices2     = range(3)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5 
results1 = []
header_row = ['Modelis', 'RandomUS_SMOTE', 'NearMiss_SMOTE', 'Cluster_SMOTE', 'RandomUS_BSMOTE', 'NearMiss_BSMOTE', 'Cluster_BSMOTE', 
              'RandomUS_SVMSMOTE', 'NearMiss_SVMSMOTE', 'Cluster_SVMSMOTE']
results1.append(header_row)

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print('Reprezentāciju modelis:',model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for k, undersampler in zip( indices2, (RandomUnderSampler(),
                                         NearMiss(),
                                         ClusterCentroids()                                       
                                          )):
    X_res, y_res = undersampler.fit_resample(features, target)                    # Veicam Unersampling
    us_name = undersampler.__class__.__name__
    print('  Pēc', us_name,' UnderSampling, klašu sadalījums:')
    unique, counts = np.unique(y_res, return_counts=True)
    print ('  ', np.asarray((unique, counts)))
    
    for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                         BorderlineSMOTE(sampling_strategy=thisdict),
                                         SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
      os_name = oversampler.__class__.__name__
      print('    ', os_name) 
      model_f1_scores = []
      fold_counter = 0
      for train_index,test_index in StratifiedKFold(n_split).split(X_res, y_res):     # 5-Fold validācija   
        x_train, x_test  = X_res[train_index], X_res[test_index]                      # Izveidojam jautājumu kopas sadalījumu
        y_train, y_test  = y_res[train_index], y_res[test_index]                      # Izveidojam kategorijas kopas sadalījumu
        
        X_res2, y_res2 = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

        model = models.Sequential()                                                   # Izveidojam Neironu tīkla modeli
        model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(4, activation='softmax'))
        model.compile(loss=['sparse_categorical_crossentropy'],
                      optimizer='adam',
                      metrics=['sparse_categorical_accuracy'])
        history = model.fit(X_res2, y_res2,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                            batch_size=batch_size,epochs=epochs,verbose=0)
        y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
        y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

        model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
        model_f1_scores.append(model_f1_avg)
        fold_counter = fold_counter + 1
        print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
  
      model_f1 = round(np.mean(model_f1_scores), 4)
      result_row.append(model_f1)
      print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all three OverSamplers and all three UnderSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_23_mixed_Under_OverSampling_results_400.csv')
result_data
# Out:
# Reprezentāciju modelis: BERT small #2
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7629
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.6863
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8097
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7588
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7934
# 	Completed for: BERT small #2  with F1 score: 0.7622
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.796
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.6966
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.769
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7251
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7381
# 	Completed for: BERT small #2  with F1 score: 0.745
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8237
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.672
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8182
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.734
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7584
# 	Completed for: BERT small #2  with F1 score: 0.7613
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5177
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7772
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8638
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8449
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8397
# 	Completed for: BERT small #2  with F1 score: 0.7687
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5904
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7867
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8309
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8361
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7745
# 	Completed for: BERT small #2  with F1 score: 0.7637
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4243
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8039
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8333
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8054
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8284
# 	Completed for: BERT small #2  with F1 score: 0.7391
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8911
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8137
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8419
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7962
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8011
# 	Completed for: BERT small #2  with F1 score: 0.8288
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8326
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.6714
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7739
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7121
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.6968
# 	Completed for: BERT small #2  with F1 score: 0.7374
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8053
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8069
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8276
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7912
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7304
# 	Completed for: BERT small #2  with F1 score: 0.7923
# Completed for  BERT small #2  with results= ['BERT small #2', 0.7622, 0.745, 0.7613, 0.7687, 0.7637, 0.7391, 0.8288, 0.7374, 0.7923]
# Reprezentāciju modelis: BERT small
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8717
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8188
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8402
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8036
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8148
# 	Completed for: BERT small  with F1 score: 0.8298
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.9079
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7959
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8679
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8335
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8476
# 	Completed for: BERT small  with F1 score: 0.8506
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8989
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8671
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8669
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8236
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8143
# 	Completed for: BERT small  with F1 score: 0.8542
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7288
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8134
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8268
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8762
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.867
# 	Completed for: BERT small  with F1 score: 0.8224
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.758
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8098
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7755
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8549
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8574
# 	Completed for: BERT small  with F1 score: 0.8111
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7377
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8601
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8763
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8973
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8671
# 	Completed for: BERT small  with F1 score: 0.8477
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8984
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8979
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.9085
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8669
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8849
# 	Completed for: BERT small  with F1 score: 0.8913
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8974
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.9087
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8558
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8549
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8973
# 	Completed for: BERT small  with F1 score: 0.8828
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8989
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8672
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8754
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.845
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9051
# 	Completed for: BERT small  with F1 score: 0.8783
# Completed for  BERT small  with results= ['BERT small', 0.8298, 0.8506, 0.8542, 0.8224, 0.8111, 0.8477, 0.8913, 0.8828, 0.8783]
# Reprezentāciju modelis: BERT multi cased
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8359
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8112
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.7957
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7736
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7653
# 	Completed for: BERT multi cased  with F1 score: 0.7963
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7982
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7504
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8163
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8111
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7958
# 	Completed for: BERT multi cased  with F1 score: 0.7944
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.82
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7659
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.767
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7763
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8052
# 	Completed for: BERT multi cased  with F1 score: 0.7869
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7328
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8973
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9287
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8268
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8759
# 	Completed for: BERT multi cased  with F1 score: 0.8523
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.752
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8777
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9396
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8686
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8422
# 	Completed for: BERT multi cased  with F1 score: 0.856
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7851
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8888
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9385
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8882
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8402
# 	Completed for: BERT multi cased  with F1 score: 0.8682
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8902
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8125
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.895
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8755
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8496
# 	Completed for: BERT multi cased  with F1 score: 0.8646
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8797
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8603
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8803
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.877
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8795
# 	Completed for: BERT multi cased  with F1 score: 0.8754
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.8598
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8062
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8595
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.917
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7438
# 	Completed for: BERT multi cased  with F1 score: 0.8373
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.7963, 0.7944, 0.7869, 0.8523, 0.856, 0.8682, 0.8646, 0.8754, 0.8373]
# Reprezentāciju modelis: BERT big
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9081
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8868
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8763
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.887
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8542
# 	Completed for: BERT big  with F1 score: 0.8825
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8888
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8577
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8764
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8858
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.8439
# 	Completed for: BERT big  with F1 score: 0.8705
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.8692
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8362
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8879
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.853
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.876
# 	Completed for: BERT big  with F1 score: 0.8645
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.741
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8266
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8748
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.948
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.917
# 	Completed for: BERT big  with F1 score: 0.8615
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7882
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8363
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.853
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8667
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.917
# 	Completed for: BERT big  with F1 score: 0.8522
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.7906
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.8468
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.8462
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8869
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9584
# 	Completed for: BERT big  with F1 score: 0.8658
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9187
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.95
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9277
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9176
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9074
# 	Completed for: BERT big  with F1 score: 0.9243
#      BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9287
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9185
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9384
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.9379
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9074
# 	Completed for: BERT big  with F1 score: 0.9262
#      SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.9187
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.9296
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.9387
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8509
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.9178
# 	Completed for: BERT big  with F1 score: 0.9111
# Completed for  BERT big  with results= ['BERT big', 0.8825, 0.8705, 0.8645, 0.8615, 0.8522, 0.8658, 0.9243, 0.9262, 0.9111]
# Reprezentāciju modelis: FastText
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8791
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8657
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8799
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9047
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9173
# 	Completed for: FastText  with F1 score: 0.8893
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8568
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8179
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.8911
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9374
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8511
# 	Completed for: FastText  with F1 score: 0.8709
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8899
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8365
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9193
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9371
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.896
# 	Completed for: FastText  with F1 score: 0.8958
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8989
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8983
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9592
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9792
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9583
# 	Completed for: FastText  with F1 score: 0.9388
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.8656
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.7496
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.6527
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7675
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8126
# 	Completed for: FastText  with F1 score: 0.7696
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.7279
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8782
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9382
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9687
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.9687
# 	Completed for: FastText  with F1 score: 0.8963
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[  0   1   2   3]
#  [122 122 122 122]]
#      SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9282
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8643
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9386
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9482
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8646
# 	Completed for: FastText  with F1 score: 0.9088
#      BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9068
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.8781
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9176
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8696
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8603
# 	Completed for: FastText  with F1 score: 0.8865
#      SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.9287
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.9087
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.9592
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.9172
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.8526
# 	Completed for: FastText  with F1 score: 0.9133
# Completed for  FastText  with results= ['FastText', 0.8893, 0.8709, 0.8958, 0.9388, 0.7696, 0.8963, 0.9088, 0.8865, 0.9133]
# Total time elapsed: 0:21:20.485701
#             Modelis  RandomUS_SMOTE  ...  NearMiss_SVMSMOTE  Cluster_SVMSMOTE
# 0     BERT small #2          0.7622  ...             0.7374            0.7923
# 1        BERT small          0.8298  ...             0.8828            0.8783
# 2  BERT multi cased          0.7963  ...             0.8754            0.8373
# 3          BERT big          0.8825  ...             0.9262            0.9111
# 4          FastText          0.8893  ...             0.8865            0.9133
#
# [5 rows x 10 columns]

# %% [markdown]
# <h3>300% OverSampling + UnderSampling uz 1000 </h3>

# %%
class_size = round(122 / 5 * 4) # klases izmērs pēc sadalīšanas K-Foldos
big_size   = round(1000 / 5 * 4)
size = 4*class_size             # katrai klasei veicam 300% jaunu piemēru izveidošanu
thisdict = {
  1: big_size,
  3: size,
  2: size,
  0: size
}
size, big_size
# Out:
# (392, 800)

# %%
bert_big_data['labels'].value_counts()
# Out:
# 1    23025
# 3      122
# 2      122
# 0      122
# Name: labels, dtype: int64

# %%
thisdict2 = {
  1: 1000,
  3: 122,
  2: 122,
  0: 122
}

# %%
indices      = range(3)
indices2     = range(3)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5 
results1 = []
header_row = ['Modelis', 'RandomUS_SMOTE', 'NearMiss_SMOTE', 'Cluster_SMOTE', 'RandomUS_BSMOTE', 'NearMiss_BSMOTE', 'Cluster_BSMOTE', 
              'RandomUS_SVMSMOTE', 'NearMiss_SVMSMOTE', 'Cluster_SVMSMOTE']
results1.append(header_row)

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print('Reprezentāciju modelis:',model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for k, undersampler in zip( indices2, (RandomUnderSampler(sampling_strategy=thisdict2),
                                         NearMiss(sampling_strategy=thisdict2),
                                         ClusterCentroids(sampling_strategy=thisdict2)                                       
                                          )):
    X_res, y_res = undersampler.fit_resample(features, target)                    # Veicam Unersampling
    us_name = undersampler.__class__.__name__
    print('  Pēc', us_name,' UnderSampling, klašu sadalījums:')
    unique, counts = np.unique(y_res, return_counts=True)
    print ('  ', np.asarray((unique, counts)))
    
    for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                         BorderlineSMOTE(sampling_strategy=thisdict),
                                         SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
      os_name = oversampler.__class__.__name__
      print('    ', os_name) 
      model_f1_scores = []
      fold_counter = 0
      for train_index,test_index in StratifiedKFold(n_split).split(X_res, y_res):     # 5-Fold validācija   
        x_train, x_test  = X_res[train_index], X_res[test_index]                      # Izveidojam jautājumu kopas sadalījumu
        y_train, y_test  = y_res[train_index], y_res[test_index]                      # Izveidojam kategorijas kopas sadalījumu
        
        X_res2, y_res2 = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

        model = models.Sequential()                                                   # Izveidojam Neironu tīkla modeli
        model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(4, activation='softmax'))
        model.compile(loss=['sparse_categorical_crossentropy'],
                      optimizer='adam',
                      metrics=['sparse_categorical_accuracy'])
        history = model.fit(X_res2, y_res2,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                            batch_size=batch_size,epochs=epochs,verbose=0)
        y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
        y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

        model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
        model_f1_scores.append(model_f1_avg)
        fold_counter = fold_counter + 1
        print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
  
      model_f1 = round(np.mean(model_f1_scores), 4)
      result_row.append(model_f1)
      print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all three OverSamplers and all three UnderSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_23_mixed_Under_OverSampling_results_300_5000.csv')
result_data
# Out:
# Reprezentāciju modelis: BERT small #2
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.769
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.731
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7836
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7702
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7868
# 	Completed for: BERT small #2  with F1 score: 0.7681
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7946
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.693
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8238
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7439
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7883
# 	Completed for: BERT small #2  with F1 score: 0.7687
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7212
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.706
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8086
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7677
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7875
# 	Completed for: BERT small #2  with F1 score: 0.7582
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4725
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7815
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8136
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8971
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8597
# 	Completed for: BERT small #2  with F1 score: 0.7649
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5237
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.7481
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7428
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.8847
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8582
# 	Completed for: BERT small #2  with F1 score: 0.7515
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5262
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8062
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.8091
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.9092
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.86
# 	Completed for: BERT small #2  with F1 score: 0.7821
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8119
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8534
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7831
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7777
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.8571
# 	Completed for: BERT small #2  with F1 score: 0.8166
#      BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.8305
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8172
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7973
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7779
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7849
# 	Completed for: BERT small #2  with F1 score: 0.8016
#      SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.7948
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.8395
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.7836
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7567
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.7239
# 	Completed for: BERT small #2  with F1 score: 0.7797
# Completed for  BERT small #2  with results= ['BERT small #2', 0.7681, 0.7687, 0.7582, 0.7649, 0.7515, 0.7821, 0.8166, 0.8016, 0.7797]
# Reprezentāciju modelis: BERT small
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7387
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7772
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8679
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.852
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8469
# 	Completed for: BERT small  with F1 score: 0.8165
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7303
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7842
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8453
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8333
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.7959
# 	Completed for: BERT small  with F1 score: 0.7978
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.7674
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7604
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.841
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7562
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8576
# 	Completed for: BERT small  with F1 score: 0.7965
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6092
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8167
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8565
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8777
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8541
# 	Completed for: BERT small  with F1 score: 0.8028
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6165
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8512
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8236
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8718
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8375
# 	Completed for: BERT small  with F1 score: 0.8001
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.6233
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.8613
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8611
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8451
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.8859
# 	Completed for: BERT small  with F1 score: 0.8153
#   Pēc ClusterCentroids  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8787
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7274
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8261
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.826
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9034
# 	Completed for: BERT small  with F1 score: 0.8323
#      BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8897
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.765
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8562
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8961
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9249
# 	Completed for: BERT small  with F1 score: 0.8664
#      SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.8839
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.7869
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.8656
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8908
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.9169
# 	Completed for: BERT small  with F1 score: 0.8688
# Completed for  BERT small  with results= ['BERT small', 0.8165, 0.7978, 0.7965, 0.8028, 0.8001, 0.8153, 0.8323, 0.8664, 0.8688]
# Reprezentāciju modelis: BERT multi cased
#   Pēc RandomUnderSampler  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7599
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7845
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8481
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7992
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7908
# 	Completed for: BERT multi cased  with F1 score: 0.7965
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7451
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7716
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.82
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7851
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8249
# 	Completed for: BERT multi cased  with F1 score: 0.7893
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7951
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.7627
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8093
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7581
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.7998
# 	Completed for: BERT multi cased  with F1 score: 0.785
#   Pēc NearMiss  UnderSampling, klašu sadalījums:
#    [[   0    1    2    3]
#  [ 122 1000  122  122]]
#      SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7536
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.9031
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8904
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8308
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8964
# 	Completed for: BERT multi cased  with F1 score: 0.8549
#      BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.7256
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8639
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.8876
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8358
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8618
# 	Completed for: BERT multi cased  with F1 score: 0.8349
#      SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.678
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.8706
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.9023
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.8819
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.8624
# 	Completed for: BERT multi cased  with F1 score: 0.839
