# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
import warnings
import pandas as pd
import numpy as np
import datetime
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold
from keras.preprocessing import text
from keras import models, layers
from imblearn.over_sampling import SMOTE, SVMSMOTE, BorderlineSMOTE, ADASYN

# %%
warnings.filterwarnings('ignore')
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets'
fasttext_data         = pd.read_csv('2020_05_09_encoded_Fasttext.csv', index_col=0)
base_data             = pd.read_csv('papildinatie_jautajumi_cleaned.csv', index_col=0)
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded'
bert_big_data         = pd.read_csv('2020_05_10_encoded_BERT_big.csv', index_col=0)
bert_multi_cased_data = pd.read_csv('2020_05_10_encoded_BERT_multi_cased.csv', index_col=0)
bert_small_2_data     = pd.read_csv('2020_05_10_encoded_BERT_small_2.csv', index_col=0)
bert_small_data       = pd.read_csv('2020_05_10_encoded_BERT_small.csv', index_col=0)
print('Papildinato jautājumu kopa: ', base_data.shape, 'FastText iekodētā datu kopa:', fasttext_data.shape)
print('BERT 1 dati:', bert_small_data.shape, 'BERT 2 dati:',  bert_small_2_data.shape, 'BERT 3 dati:', bert_multi_cased_data.shape, 'BERT 4 dati:', bert_big_data.shape)
# Out:
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded
# Papildinato jautājumu kopa:  (23391, 2) FastText iekodētā datu kopa: (23391, 301)
# BERT 1 dati: (23391, 257) BERT 2 dati: (23391, 257) BERT 3 dati: (23391, 769) BERT 4 dati: (23391, 769)

# %%
def transformResults(results):            # funkcija, kas pārvērš saņemtus rezultātus, izvēloties populārākās klases indeksu katrā masīva rindā
    mod_results = []
    for result in results:
        out = np.argmax(result)
        mod_results.append(out)
    mod_results = np.array(mod_results)  
    return mod_results

# %% [markdown]
# <h3>100% OverSampling</h3>

# %%
indices       = range(4)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'SVMSMOTE', 'BorderlineSMOTE', 'ADASYN']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 2*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 196

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print(model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict),
                                       SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
    os_name = oversampler.__class__.__name__
    print('  ', os_name)
    model_f1_scores = []
    fold_counter = 0
    for train_index,test_index in StratifiedKFold(n_split).split(features, target): # 5-Fold validācija 
      x_train, x_test  = features[train_index], features[test_index]                 # Izveidojam jautājumu kopas sadalījumu
      y_train, y_test  = target[train_index], target[test_index]                     # Izveidojam kategorijas kopas sadalījumu
        
      X_res, y_res = oversampler.fit_resample(x_train, y_train)                     # Veicam Oversampling
      
      model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
      model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
      model.add(layers.Dense(64, activation='relu'))
      model.add(layers.Dense(4, activation='softmax'))
      model.compile(loss=['sparse_categorical_crossentropy'],
                    optimizer='adam',
                    metrics=['sparse_categorical_accuracy'])
      history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                          batch_size=batch_size,epochs=epochs,verbose=0)
      y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
      y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

      model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
      model_f1_scores.append(model_f1_avg)
      fold_counter = fold_counter + 1
      print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
    # After K-Fold validation
    model_f1 = round(np.mean(model_f1_scores), 4)
    result_row.append(model_f1)
    print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all four OverSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_20_OverSampling_results_1.csv')
result_data
# Out:
# BERT small #2
#    SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4984
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4475
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6605
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7027
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5317
# 	Completed for: BERT small #2  with F1 score: 0.5682
#    BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.494
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4482
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6602
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.5879
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.4756
# 	Completed for: BERT small #2  with F1 score: 0.5332
#    SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.372
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4152
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6334
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6322
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5607
# 	Completed for: BERT small #2  with F1 score: 0.5227
# Completed for  BERT small #2  with results= ['BERT small #2', 0.5682, 0.5332, 0.5227]
# BERT small
#    SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5213
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.6004
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.6476
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7858
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.5721
# 	Completed for: BERT small  with F1 score: 0.6254
#    BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5012
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5559
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7177
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7479
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.6098
# 	Completed for: BERT small  with F1 score: 0.6265
#    SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5313
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.4524
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.658
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.6847
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.5733
# 	Completed for: BERT small  with F1 score: 0.5799
# Completed for  BERT small  with results= ['BERT small', 0.6254, 0.6265, 0.5799]
# BERT multi cased
#    SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5487
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5235
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.723
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.6385
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.5813
# 	Completed for: BERT multi cased  with F1 score: 0.603
#    BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.4848
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.4092
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.6777
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.6485
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.5941
# 	Completed for: BERT multi cased  with F1 score: 0.5629
#    SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.4307
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5191
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.7191
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7656
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.5662
# 	Completed for: BERT multi cased  with F1 score: 0.6001
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.603, 0.5629, 0.6001]
# BERT big
#    SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.5575
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.595
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.6981
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.7372
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6358
# 	Completed for: BERT big  with F1 score: 0.6447
#    BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.5559
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5377
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7624
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8184
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6628
# 	Completed for: BERT big  with F1 score: 0.6674
#    SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.6018
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5685
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7411
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.8155
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6329
# 	Completed for: BERT big  with F1 score: 0.672
# Completed for  BERT big  with results= ['BERT big', 0.6447, 0.6674, 0.672]
# FastText
#    SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.5673
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5841
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7859
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7786
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6774
# 	Completed for: FastText  with F1 score: 0.6787
#    BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.587
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5321
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7883
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8065
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7529
# 	Completed for: FastText  with F1 score: 0.6934
#    SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.5833
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5247
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7874
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7987
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6503
# 	Completed for: FastText  with F1 score: 0.6689
# Completed for  FastText  with results= ['FastText', 0.6787, 0.6934, 0.6689]
# Total time elapsed: 0:40:12.107828
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     496         result = _convert_object_array(
# --> 497             content, columns, dtype=dtype, coerce_float=coerce_float
#     498         )
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     580             raise AssertionError(
# --> 581                 f"{len(columns)} columns passed, passed data had "
#     582                 f"{len(content)} columns"
#
# AssertionError: 5 columns passed, passed data had 4 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-de9692edb0f2> in <module>()
#      55
#      56 # Saglabājam visus rezultātus
# ---> 57 result_data = pd.DataFrame(results1[1:], columns=results1[0])
#      58 result_data.to_csv('2020_05_20_OverSampling_results_1.csv')
#      59 result_data
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     472                     if is_named_tuple(data[0]) and columns is None:
#     473                         columns = data[0]._fields
# --> 474                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     475                     columns = ensure_index(columns)
#     476
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     459         return [], []  # columns if columns is not None else []
#     460     if isinstance(data[0], (list, tuple)):
# --> 461         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     462     elif isinstance(data[0], abc.Mapping):
#     463         return _list_of_dict_to_arrays(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     498         )
#     499     except AssertionError as e:
# --> 500         raise ValueError(e) from e
#     501     return result
#     502
#
# ValueError: 5 columns passed, passed data had 4 columns

# %%
header_row = ['Modelis', 'SMOTE', 'SVMSMOTE', 'BorderlineSMOTE']
result_data = pd.DataFrame(results1[1:], columns=header_row)
result_data.to_csv('2020_05_20_OverSampling_results_1.csv')
result_data
# Out:
#             Modelis   SMOTE  SVMSMOTE  BorderlineSMOTE
# 0     BERT small #2  0.5682    0.5332           0.5227
# 1        BERT small  0.6254    0.6265           0.5799
# 2  BERT multi cased  0.6030    0.5629           0.6001
# 3          BERT big  0.6447    0.6674           0.6720
# 4          FastText  0.6787    0.6934           0.6689

# %% [markdown]
# <h3>200% OverSampling</h3>

# %%
indices       = range(4)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'SVMSMOTE', 'BorderlineSMOTE']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 3*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 294

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print(model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict),
                                       SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
    os_name = oversampler.__class__.__name__
    print('  ', os_name)
    model_f1_scores = []
    fold_counter = 0
    for train_index,test_index in StratifiedKFold(n_split).split(features, target): # 5-Fold validācija 
      x_train, x_test  = features[train_index], features[test_index]                 # Izveidojam jautājumu kopas sadalījumu
      y_train, y_test  = target[train_index], target[test_index]                     # Izveidojam kategorijas kopas sadalījumu
        
      X_res, y_res = oversampler.fit_resample(x_train, y_train)                     # Veicam Oversampling
      
      model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
      model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
      model.add(layers.Dense(64, activation='relu'))
      model.add(layers.Dense(4, activation='softmax'))
      model.compile(loss=['sparse_categorical_crossentropy'],
                    optimizer='adam',
                    metrics=['sparse_categorical_accuracy'])
      history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                          batch_size=batch_size,epochs=epochs,verbose=0)
      y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
      y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

      model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
      model_f1_scores.append(model_f1_avg)
      fold_counter = fold_counter + 1
      print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
    # After K-Fold validation
    model_f1 = round(np.mean(model_f1_scores), 4)
    result_row.append(model_f1)
    print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all four OverSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_20_OverSampling_results_200.csv')
result_data
# Out:
# BERT small #2
#    SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5071
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4975
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6211
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6907
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.4552
# 	Completed for: BERT small #2  with F1 score: 0.5543
#    BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.475
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4852
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6822
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6683
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.4496
# 	Completed for: BERT small #2  with F1 score: 0.5521
#    SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4951
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4799
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6471
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7201
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.4731
# 	Completed for: BERT small #2  with F1 score: 0.5631
# Completed for  BERT small #2  with results= ['BERT small #2', 0.5543, 0.5521, 0.5631]
# BERT small
#    SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.4811
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.6002
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.7065
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.6908
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.5922
# 	Completed for: BERT small  with F1 score: 0.6142
#    BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.4981
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5728
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.6362
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7848
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.6499
# 	Completed for: BERT small  with F1 score: 0.6284
#    SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5202
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5373
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.5791
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7616
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.6289
# 	Completed for: BERT small  with F1 score: 0.6054
# Completed for  BERT small  with results= ['BERT small', 0.6142, 0.6284, 0.6054]
# BERT multi cased
#    SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5269
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5134
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.6927
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.6758
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.6444
# 	Completed for: BERT multi cased  with F1 score: 0.6106
#    BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5038
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.4593
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.6809
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.6812
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.6262
# 	Completed for: BERT multi cased  with F1 score: 0.5903
#    SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.548
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5416
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.7318
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7656
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.5918
# 	Completed for: BERT multi cased  with F1 score: 0.6358
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.6106, 0.5903, 0.6358]
# BERT big
#    SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.577
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.6143
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7383
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.746
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6722
# 	Completed for: BERT big  with F1 score: 0.6696
#    BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.566
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5882
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7647
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.6939
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6459
# 	Completed for: BERT big  with F1 score: 0.6517
#    SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.5619
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5148
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7532
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.6402
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.7306
# 	Completed for: BERT big  with F1 score: 0.6401
# Completed for  BERT big  with results= ['BERT big', 0.6696, 0.6517, 0.6401]
# FastText
#    SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.5949
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5408
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7774
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7384
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6316
# 	Completed for: FastText  with F1 score: 0.6566
#    BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.5738
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5914
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7237
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7927
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7155
# 	Completed for: FastText  with F1 score: 0.6794
#    SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.5859
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5799
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7978
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.8212
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6903
# 	Completed for: FastText  with F1 score: 0.695
# Completed for  FastText  with results= ['FastText', 0.6566, 0.6794, 0.695]
# Total time elapsed: 0:39:53.549200
#             Modelis   SMOTE  SVMSMOTE  BorderlineSMOTE
# 0     BERT small #2  0.5543    0.5521           0.5631
# 1        BERT small  0.6142    0.6284           0.6054
# 2  BERT multi cased  0.6106    0.5903           0.6358
# 3          BERT big  0.6696    0.6517           0.6401
# 4          FastText  0.6566    0.6794           0.6950

# %% [markdown]
# <h3>300% OverSampling</h3>

# %%
indices       = range(4)
dataset_list = [bert_small_2_data, bert_small_data, bert_multi_cased_data, bert_big_data, fasttext_data]
model_names  = ['BERT small #2', 'BERT small', 'BERT multi cased', 'BERT big', 'FastText']
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'SVMSMOTE', 'BorderlineSMOTE']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 4*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 392

# %%
exec_start = datetime.datetime.now()
for dataset in dataset_list:
  print(model_names[counter])
  result_row = []
  result_row.append(model_names[counter])
  col_count = len(dataset.columns)                                                # Veicam datu kopas dimensionalitātes saglabāšanu
  features = dataset.iloc[:,:col_count-1]                                         # Jautājumu reprezentācijas
  target = dataset.iloc[:,col_count-1:]                                           # Jautājumu kategorijas
  features = features.to_numpy()                                                  # Tipu maiņa ērtākai tālākai darbībai
  target = target.to_numpy()

  for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict),
                                       SVMSMOTE(sampling_strategy=thisdict)                                     
                                        )):
    os_name = oversampler.__class__.__name__
    print('  ', os_name)
    model_f1_scores = []
    fold_counter = 0
    for train_index,test_index in StratifiedKFold(n_split).split(features, target): # 5-Fold validācija 
      x_train, x_test  = features[train_index], features[test_index]                 # Izveidojam jautājumu kopas sadalījumu
      y_train, y_test  = target[train_index], target[test_index]                     # Izveidojam kategorijas kopas sadalījumu
        
      X_res, y_res = oversampler.fit_resample(x_train, y_train)                     # Veicam Oversampling
      
      model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
      model.add(layers.Dense(256, activation='relu', input_shape=(col_count-1,)))
      model.add(layers.Dense(64, activation='relu'))
      model.add(layers.Dense(4, activation='softmax'))
      model.compile(loss=['sparse_categorical_crossentropy'],
                    optimizer='adam',
                    metrics=['sparse_categorical_accuracy'])
      history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                          batch_size=batch_size,epochs=epochs,verbose=0)
      y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
      y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

      model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
      model_f1_scores.append(model_f1_avg)
      fold_counter = fold_counter + 1
      print('\t\tCompleted for model: ',model_names[counter],' K-Fold #', fold_counter, 'F1 score:', model_f1_avg)
    # After K-Fold validation
    model_f1 = round(np.mean(model_f1_scores), 4)
    result_row.append(model_f1)
    print('\tCompleted for:', model_names[counter],' with F1 score:',model_f1)  
  #After all four OverSamplers
  results1.append(result_row)
  print('Completed for ', model_names[counter], ' with results=', result_row)
  counter = counter + 1

#In the very end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_20_OverSampling_results_200.csv')
result_data
# Out:
# BERT small #2
#    SMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4196
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4777
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6282
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7165
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5443
# 	Completed for: BERT small #2  with F1 score: 0.5573
#    BorderlineSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.4659
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.4894
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.6894
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.6551
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.4392
# 	Completed for: BERT small #2  with F1 score: 0.5478
#    SVMSMOTE
# 		Completed for model:  BERT small #2  K-Fold # 1 F1 score: 0.5173
# 		Completed for model:  BERT small #2  K-Fold # 2 F1 score: 0.5354
# 		Completed for model:  BERT small #2  K-Fold # 3 F1 score: 0.676
# 		Completed for model:  BERT small #2  K-Fold # 4 F1 score: 0.7185
# 		Completed for model:  BERT small #2  K-Fold # 5 F1 score: 0.5271
# 	Completed for: BERT small #2  with F1 score: 0.5949
# Completed for  BERT small #2  with results= ['BERT small #2', 0.5573, 0.5478, 0.5949]
# BERT small
#    SMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5139
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5776
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.6397
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.7051
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.6086
# 	Completed for: BERT small  with F1 score: 0.609
#    BorderlineSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.524
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5611
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.6079
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.785
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.5601
# 	Completed for: BERT small  with F1 score: 0.6076
#    SVMSMOTE
# 		Completed for model:  BERT small  K-Fold # 1 F1 score: 0.5296
# 		Completed for model:  BERT small  K-Fold # 2 F1 score: 0.5642
# 		Completed for model:  BERT small  K-Fold # 3 F1 score: 0.6245
# 		Completed for model:  BERT small  K-Fold # 4 F1 score: 0.8021
# 		Completed for model:  BERT small  K-Fold # 5 F1 score: 0.5868
# 	Completed for: BERT small  with F1 score: 0.6214
# Completed for  BERT small  with results= ['BERT small', 0.609, 0.6076, 0.6214]
# BERT multi cased
#    SMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5276
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5692
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.6495
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7515
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.6139
# 	Completed for: BERT multi cased  with F1 score: 0.6223
#    BorderlineSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5114
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.4939
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.7207
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7243
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.6097
# 	Completed for: BERT multi cased  with F1 score: 0.612
#    SVMSMOTE
# 		Completed for model:  BERT multi cased  K-Fold # 1 F1 score: 0.5579
# 		Completed for model:  BERT multi cased  K-Fold # 2 F1 score: 0.5152
# 		Completed for model:  BERT multi cased  K-Fold # 3 F1 score: 0.6633
# 		Completed for model:  BERT multi cased  K-Fold # 4 F1 score: 0.7495
# 		Completed for model:  BERT multi cased  K-Fold # 5 F1 score: 0.618
# 	Completed for: BERT multi cased  with F1 score: 0.6208
# Completed for  BERT multi cased  with results= ['BERT multi cased', 0.6223, 0.612, 0.6208]
# BERT big
#    SMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.5105
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5381
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.748
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.7702
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.6852
# 	Completed for: BERT big  with F1 score: 0.6504
#    BorderlineSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.4916
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5632
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7816
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.779
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.7275
# 	Completed for: BERT big  with F1 score: 0.6686
#    SVMSMOTE
# 		Completed for model:  BERT big  K-Fold # 1 F1 score: 0.5997
# 		Completed for model:  BERT big  K-Fold # 2 F1 score: 0.5098
# 		Completed for model:  BERT big  K-Fold # 3 F1 score: 0.7453
# 		Completed for model:  BERT big  K-Fold # 4 F1 score: 0.7535
# 		Completed for model:  BERT big  K-Fold # 5 F1 score: 0.606
# 	Completed for: BERT big  with F1 score: 0.6429
# Completed for  BERT big  with results= ['BERT big', 0.6504, 0.6686, 0.6429]
# FastText
#    SMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.6195
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5806
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7584
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7541
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.679
# 	Completed for: FastText  with F1 score: 0.6783
#    BorderlineSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.6332
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5415
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7758
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7996
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.6934
# 	Completed for: FastText  with F1 score: 0.6887
#    SVMSMOTE
# 		Completed for model:  FastText  K-Fold # 1 F1 score: 0.6157
# 		Completed for model:  FastText  K-Fold # 2 F1 score: 0.5912
# 		Completed for model:  FastText  K-Fold # 3 F1 score: 0.7886
# 		Completed for model:  FastText  K-Fold # 4 F1 score: 0.7852
# 		Completed for model:  FastText  K-Fold # 5 F1 score: 0.7163
# 	Completed for: FastText  with F1 score: 0.6994
# Completed for  FastText  with results= ['FastText', 0.6783, 0.6887, 0.6994]
# Total time elapsed: 0:39:15.515805
#             Modelis   SMOTE  SVMSMOTE  BorderlineSMOTE
# 0     BERT small #2  0.5573    0.5478           0.5949
# 1        BERT small  0.6090    0.6076           0.6214
# 2  BERT multi cased  0.6223    0.6120           0.6208
# 3          BERT big  0.6504    0.6686           0.6429
# 4          FastText  0.6783    0.6887           0.6994

# %% [markdown]
# <h3>Bāzlīnija 100%

# %%
col_count = len(base_data.columns)
features = base_data['Question'].to_numpy().astype('str')
target = base_data['labels']

# %%
max_words = 2000
# Text pre-processing
tokenize = text.Tokenizer(num_words=max_words, char_level=False)                # izveidojam Tokenizer ar noteikto vārdnīcas izmēru
tokenize.fit_on_texts(features)                                                 # apmācām Tokenizer uz mūsu datiem
X = tokenize.texts_to_matrix(features)                                          # pārveidojam treniņdatus par tekstvienību vektoriem
print('Tokenizer done:', max_words, X.shape)
# Out:
# Tokenizer done: 2000 (23391, 2000)

# %%
indices       = range(2)
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'BorderlineSMOTE']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 2*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 196

# %%
exec_start = datetime.datetime.now()
keras_row = ['Keras Baseline']
naive_row = ['Naive Bayes']
for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict)                                    
                                        )):
  os_name = oversampler.__class__.__name__
  print(os_name)
  f1_scores_naive = []                                                          # Creating an empty array of f1 scores 
  f1_scores_keras = []
  fold_counter = 0
  for train_index,test_index in StratifiedKFold(n_split).split(X, target):      # 5-Fold validācija 
    x_train, x_test  = X[train_index], X[test_index]                            # Izveidojam jautājumu kopas sadalījumu
    y_train, y_test  = target[train_index], target[test_index]                  # Izveidojam kategorijas kopas sadalījumu
        
    X_res, y_res = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

    ### Naive Bayes ###
    naive_bayes = MultinomialNB()                                               # Izveidojam Naive Bayes modeli
    naive_bayes.fit(X_res, y_res)                                               # Trenējam modeli uz treniņdatiem
    naive_y_pred = naive_bayes.predict(x_test)
    naive_f1_avg = round(f1_score(y_test, naive_y_pred, average='macro'),4)     # Fiksējam Naive Bayes f1 vidējo rezultātu
    f1_scores_naive.append(naive_f1_avg)

    ### Keras Sequential Baseline ###  
    model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
    model.add(layers.Dense(256, activation='relu', input_shape=(max_words,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(4, activation='softmax'))
    model.compile(loss=['sparse_categorical_crossentropy'],
                  optimizer='adam',
                  metrics=['sparse_categorical_accuracy'])
    history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                        batch_size=batch_size,epochs=epochs,verbose=0)
    y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
    y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

    model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
    f1_scores_keras.append(model_f1_avg)
    fold_counter = fold_counter + 1
    print('\tCompleted for:', os_name,' K-Fold #',counter, ' Naive Bayes score:',naive_f1_avg, ' Keras score:',model_f1_avg)
  # After K-Fold validation
  f1_avg_naive = round(np.mean(f1_scores_naive), 4)
  f1_avg_keras = round(np.mean(f1_scores_keras),4)
  keras_row.append(f1_avg_keras)
  naive_row.append(f1_avg_naive)

#After all two OverSamplers
results1.append(keras_row)
results1.append(naive_row)
#In the end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_22_OverSampling_base_results_100.csv')
result_data
# Out:
# SMOTE
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5596  Keras score: 0.614
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5086  Keras score: 0.5088
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.6199  Keras score: 0.7129
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5911  Keras score: 0.7674
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5527  Keras score: 0.6567
# BorderlineSMOTE
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5442  Keras score: 0.5686
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5028  Keras score: 0.5396
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.623  Keras score: 0.7305
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.6228  Keras score: 0.7791
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5431  Keras score: 0.6688
# Total time elapsed: 0:05:36.934052
#           Modelis   SMOTE  BorderlineSMOTE
# 0  Keras Baseline  0.6520           0.6573
# 1     Naive Bayes  0.5664           0.5672

# %% [markdown]
# <h3>Bāzlīnijas 200% </h3>

# %%
indices       = range(2)
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'BorderlineSMOTE']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 3*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 294

# %%
exec_start = datetime.datetime.now()
keras_row = ['Keras Baseline']
naive_row = ['Naive Bayes']
for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict)                                    
                                        )):
  os_name = oversampler.__class__.__name__
  print(os_name)
  f1_scores_naive = []                                                          # Creating an empty array of f1 scores 
  f1_scores_keras = []
  fold_counter = 0
  for train_index,test_index in StratifiedKFold(n_split).split(X, target):      # 5-Fold validācija 
    x_train, x_test  = X[train_index], X[test_index]                            # Izveidojam jautājumu kopas sadalījumu
    y_train, y_test  = target[train_index], target[test_index]                  # Izveidojam kategorijas kopas sadalījumu
        
    X_res, y_res = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

    ### Naive Bayes ###
    naive_bayes = MultinomialNB()                                               # Izveidojam Naive Bayes modeli
    naive_bayes.fit(X_res, y_res)                                               # Trenējam modeli uz treniņdatiem
    naive_y_pred = naive_bayes.predict(x_test)
    naive_f1_avg = round(f1_score(y_test, naive_y_pred, average='macro'),4)     # Fiksējam Naive Bayes f1 vidējo rezultātu
    f1_scores_naive.append(naive_f1_avg)

    ### Keras Sequential Baseline ###  
    model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
    model.add(layers.Dense(256, activation='relu', input_shape=(max_words,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(4, activation='softmax'))
    model.compile(loss=['sparse_categorical_crossentropy'],
                  optimizer='adam',
                  metrics=['sparse_categorical_accuracy'])
    history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                        batch_size=batch_size,epochs=epochs,verbose=0)
    y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
    y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

    model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
    f1_scores_keras.append(model_f1_avg)
    fold_counter = fold_counter + 1
    print('\tCompleted for:', os_name,' K-Fold #',counter, ' Naive Bayes score:',naive_f1_avg, ' Keras score:',model_f1_avg)
  # After K-Fold validation
  f1_avg_naive = round(np.mean(f1_scores_naive), 4)
  f1_avg_keras = round(np.mean(f1_scores_keras),4)
  keras_row.append(f1_avg_keras)
  naive_row.append(f1_avg_naive)

#After all two OverSamplers
results1.append(keras_row)
results1.append(naive_row)
#In the end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_22_OverSampling_base_results_200.csv')
result_data
# Out:
# SMOTE
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5284  Keras score: 0.5727
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5326  Keras score: 0.4895
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.6275  Keras score: 0.6877
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.6014  Keras score: 0.7772
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5367  Keras score: 0.6739
# BorderlineSMOTE
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5486  Keras score: 0.5849
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5247  Keras score: 0.5048
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.6244  Keras score: 0.7208
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.626  Keras score: 0.7633
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5778  Keras score: 0.696
# Total time elapsed: 0:05:41.311675
#           Modelis   SMOTE  BorderlineSMOTE
# 0  Keras Baseline  0.6402           0.6540
# 1     Naive Bayes  0.5653           0.5803

# %% [markdown]
# <h3>Bāzlīnijas 300% </h3>

# %%
indices       = range(2)
n_split = 5
counter = 0
batch_size = 64
epochs = 5  
results1 = []
header_row = ['Modelis', 'SMOTE', 'BorderlineSMOTE']
results1.append(header_row)

# %%
class_size = round(122 / 5 * 4)
size = 4*class_size
thisdict = {
  1: 18420,
  3: size,
  2: size,
  0: size
}
size
# Out:
# 392

# %%
exec_start = datetime.datetime.now()
keras_row = ['Keras Baseline']
naive_row = ['Naive Bayes']
for i, oversampler in zip( indices, (SMOTE(sampling_strategy=thisdict),
                                       BorderlineSMOTE(sampling_strategy=thisdict)                                    
                                        )):
  os_name = oversampler.__class__.__name__
  print(os_name)
  f1_scores_naive = []                                                          # Creating an empty array of f1 scores 
  f1_scores_keras = []
  fold_counter = 0
  for train_index,test_index in StratifiedKFold(n_split).split(X, target):      # 5-Fold validācija 
    x_train, x_test  = X[train_index], X[test_index]                            # Izveidojam jautājumu kopas sadalījumu
    y_train, y_test  = target[train_index], target[test_index]                  # Izveidojam kategorijas kopas sadalījumu
        
    X_res, y_res = oversampler.fit_resample(x_train, y_train)                   # Veicam Oversampling

    ### Naive Bayes ###
    naive_bayes = MultinomialNB()                                               # Izveidojam Naive Bayes modeli
    naive_bayes.fit(X_res, y_res)                                               # Trenējam modeli uz treniņdatiem
    naive_y_pred = naive_bayes.predict(x_test)
    naive_f1_avg = round(f1_score(y_test, naive_y_pred, average='macro'),4)     # Fiksējam Naive Bayes f1 vidējo rezultātu
    f1_scores_naive.append(naive_f1_avg)

    ### Keras Sequential Baseline ###  
    model = models.Sequential()                                                 # Izveidojam Neironu tīkla modeli
    model.add(layers.Dense(256, activation='relu', input_shape=(max_words,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(4, activation='softmax'))
    model.compile(loss=['sparse_categorical_crossentropy'],
                  optimizer='adam',
                  metrics=['sparse_categorical_accuracy'])
    history = model.fit(X_res, y_res,                                         # Veicam modeļa trenēšanu, izmantojot kombinēto datu kopu
                        batch_size=batch_size,epochs=epochs,verbose=0)
    y_pred = model.predict(x_test)                                              # Prasam modelim paredzēt testa datiem kategorijas
    y_pred2 = transformResults(y_pred)                                          # Pārveidojam rezultātus

    model_f1_avg = round(f1_score(y_test, y_pred2, average='macro'),4)          # Fiksējam f1 vidējo rezultātu kārtējā K-Foldā
    f1_scores_keras.append(model_f1_avg)
    fold_counter = fold_counter + 1
    print('\tCompleted for:', os_name,' K-Fold #',counter, ' Naive Bayes score:',naive_f1_avg, ' Keras score:',model_f1_avg)
  # After K-Fold validation
  f1_avg_naive = round(np.mean(f1_scores_naive), 4)
  f1_avg_keras = round(np.mean(f1_scores_keras),4)
  keras_row.append(f1_avg_keras)
  naive_row.append(f1_avg_naive)

#After all two OverSamplers
results1.append(keras_row)
results1.append(naive_row)
#In the end - fix the execution time
exec_end = datetime.datetime.now()
exec_elapsed = exec_end - exec_start
print('Total time elapsed:', exec_elapsed)

# Saglabājam visus rezultātus
result_data = pd.DataFrame(results1[1:], columns=results1[0])
result_data.to_csv('2020_05_22_OverSampling_base_results_300.csv')
result_data
# Out:
# SMOTE
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5443  Keras score: 0.6145
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5449  Keras score: 0.5032
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.6316  Keras score: 0.7491
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.596  Keras score: 0.7438
# 	Completed for: SMOTE  K-Fold # 0  Naive Bayes score: 0.5416  Keras score: 0.6869
# BorderlineSMOTE
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5377  Keras score: 0.5822
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.529  Keras score: 0.5241
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.6146  Keras score: 0.7251
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.6008  Keras score: 0.7687
# 	Completed for: BorderlineSMOTE  K-Fold # 0  Naive Bayes score: 0.5692  Keras score: 0.6838
# Total time elapsed: 0:05:45.111141
#           Modelis   SMOTE  BorderlineSMOTE
# 0  Keras Baseline  0.6595           0.6568
# 1     Naive Bayes  0.5717           0.5703
