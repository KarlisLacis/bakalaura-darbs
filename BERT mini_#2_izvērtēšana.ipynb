# %% [markdown]
# <h2>Izvērtēšana</h2>

# %%
from google.colab import drive
import numpy as np
import pandas as pd
import datetime
import warnings
warnings.filterwarnings('ignore')
drive.mount('/gdrive')
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded'

# %%
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/'
eval_data = pd.read_csv('2020_05_24_BERT_small_2_izvertesana.csv', index_col=0)
col_count = len(eval_data.columns) - 1
X = eval_data.iloc[:,:col_count]
Y = eval_data.iloc[:,col_count:]
print(X.shape, Y.shape)
# Out:
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets
# (100, 256) (100, 1)

# %%
def transformResults(results):
    mod_results = []
    for result in results:
        out = np.argmax(result)
        mod_results.append(out)
    mod_results = np.array(mod_results)    
    return mod_results

# %% [markdown]
# <h3>Nepapildināto jautājumu izvērtēšana</h3>

# %%
sakotnejie = pd.read_csv('Encoded_labeled_BERT_small_other.csv', index_col=0)
print(sakotnejie.shape)
col_count = len(sakotnejie.columns) - 1
print(col_count)
features = sakotnejie.iloc[:,:col_count]
target = sakotnejie.iloc[:,col_count:]
print(features.shape, target.shape)
# Out:
# (23217, 257)
# 256
# (23217, 256) (23217, 1)

# %%
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
y_test = Y.to_numpy()

model_scores = []
counter = 0
for i in range(10):
  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(features, target,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.2744, 0.3653, 0.2263, 0.1875, 0.1948, 0.1387, 0.2898, 0.1387, 0.1761, 0.2601]
# BERT small #2 final score: 0.23

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.1387
#               precision    recall  f1-score   support
#
#   akadēmisks       0.00      0.00      0.00        25
#         citi       0.26      1.00      0.41        25
#  darba laiks       1.00      0.08      0.15        25
#    dokumenti       0.00      0.00      0.00        25
#
#     accuracy                           0.27       100
#    macro avg       0.31      0.27      0.14       100
# weighted avg       0.31      0.27      0.14       100
#
# [[ 0 25  0  0]
#  [ 0 25  0  0]
#  [ 0 23  2  0]
#  [ 0 25  0  0]]
# [[0.   1.   0.   0.  ]
#  [0.   1.   0.   0.  ]
#  [0.   0.92 0.08 0.  ]
#  [0.   1.   0.   0.  ]]

# %% [markdown]
# <h2>Papildināto jautājumu izvērtēšana</h2>

# %%
# %cd '/gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded'
papildinatie = pd.read_csv('2020_05_10_encoded_BERT_small_2.csv', index_col=0)
print(papildinatie.shape)
col_count = len(papildinatie.columns) - 1
features = papildinatie.iloc[:,:col_count]
target = papildinatie.iloc[:,col_count:]
print(features.shape, target.shape)
# Out:
# /gdrive/My Drive/LU/LU DF/8. semestris/Bakalaura Darbs/Datasets/BERT_encoded
# (23391, 257)
# (23391, 256) (23391, 1)

# %%
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
y_test = Y.to_numpy()

model_scores = []
counter = 0
for i in range(10):
  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(features, target,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.5493, 0.4831, 0.3321, 0.5097, 0.4026, 0.5044, 0.4751, 0.5663, 0.4665, 0.4465]
# BERT small #2 final score: 0.47

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.4892
#               precision    recall  f1-score   support
#
#   akadēmisks       1.00      0.76      0.86        25
#         citi       0.35      1.00      0.52        25
#  darba laiks       1.00      0.08      0.15        25
#    dokumenti       0.88      0.28      0.42        25
#
#     accuracy                           0.53       100
#    macro avg       0.81      0.53      0.49       100
# weighted avg       0.81      0.53      0.49       100
#
# [[19  5  0  1]
#  [ 0 25  0  0]
#  [ 0 23  2  0]
#  [ 0 18  0  7]]
# [[0.76 0.2  0.   0.04]
#  [0.   1.   0.   0.  ]
#  [0.   0.92 0.08 0.  ]
#  [0.   0.72 0.   0.28]]

# %% [markdown]
# <h2>UnderSampling izvērtēšana</h2>

# %%
from imblearn.under_sampling import NearMiss
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

model_scores = []
counter = 0
for i in range(10):
  undersampler = NearMiss()
  X_res, y_res = undersampler.fit_resample(features, target)                   # Veicam Unersampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small scores:', model_scores)
print('BERT small final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small scores: [0.4783, 0.5213, 0.494, 0.5199, 0.5114, 0.4549, 0.4991, 0.5025, 0.5003, 0.5024]
# BERT small final score: 0.5

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.4856
#               precision    recall  f1-score   support
#
#   akadēmisks       0.81      0.88      0.85        25
#         citi       0.33      0.04      0.07        25
#  darba laiks       0.67      0.40      0.50        25
#    dokumenti       0.38      0.84      0.53        25
#
#     accuracy                           0.54       100
#    macro avg       0.55      0.54      0.49       100
# weighted avg       0.55      0.54      0.49       100
#
# [[22  0  1  2]
#  [ 2  1  4 18]
#  [ 0  1 10 14]
#  [ 3  1  0 21]]
# [[0.88 0.   0.04 0.08]
#  [0.08 0.04 0.16 0.72]
#  [0.   0.04 0.4  0.56]
#  [0.12 0.04 0.   0.84]]

# %% [markdown]
# <h2>OverSampling izvērtēšana</h2>

# %% [markdown]
# <h3>Oversampling apjoms = 100%</h3>

# %%
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 2*122
thisdict = {
  1: 23025,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)

model_scores = []
counter = 0
for i in range(10):
  undersampler = NearMiss()
  X_res, y_res = oversampler.fit_resample(features, target)                       # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.6182, 0.5626, 0.5387, 0.6165, 0.5162, 0.6356, 0.6034, 0.6127, 0.6358, 0.674]
# BERT small #2 final score: 0.6

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.5902
#               precision    recall  f1-score   support
#
#   akadēmisks       1.00      0.72      0.84        25
#         citi       0.38      0.96      0.55        25
#  darba laiks       1.00      0.28      0.44        25
#    dokumenti       0.83      0.40      0.54        25
#
#     accuracy                           0.59       100
#    macro avg       0.80      0.59      0.59       100
# weighted avg       0.80      0.59      0.59       100
#
# [[18  6  0  1]
#  [ 0 24  0  1]
#  [ 0 18  7  0]
#  [ 0 15  0 10]]
# [[0.72 0.24 0.   0.04]
#  [0.   0.96 0.   0.04]
#  [0.   0.72 0.28 0.  ]
#  [0.   0.6  0.   0.4 ]]

# %% [markdown]
# <h3>Oversampling apjoms = 200%</h3>

# %%
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 3*122
thisdict = {
  1: 23025,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)

model_scores = []
counter = 0
for i in range(10):
  undersampler = NearMiss()
  X_res, y_res = oversampler.fit_resample(features, target)                       # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.5454, 0.6736, 0.4702, 0.5612, 0.6642, 0.4846, 0.5813, 0.5928, 0.6096, 0.637]
# BERT small #2 final score: 0.58

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.6013
#               precision    recall  f1-score   support
#
#   akadēmisks       1.00      0.72      0.84        25
#         citi       0.39      0.96      0.55        25
#  darba laiks       1.00      0.28      0.44        25
#    dokumenti       0.85      0.44      0.58        25
#
#     accuracy                           0.60       100
#    macro avg       0.81      0.60      0.60       100
# weighted avg       0.81      0.60      0.60       100
#
# [[18  6  0  1]
#  [ 0 24  0  1]
#  [ 0 18  7  0]
#  [ 0 14  0 11]]
# [[0.72 0.24 0.   0.04]
#  [0.   0.96 0.   0.04]
#  [0.   0.72 0.28 0.  ]
#  [0.   0.56 0.   0.44]]

# %% [markdown]
# <h3>Oversampling apjoms = 300%</h3>

# %%
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 4*122
thisdict = {
  1: 23025,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)

model_scores = []
counter = 0
for i in range(10):
  undersampler = NearMiss()
  X_res, y_res = oversampler.fit_resample(features, target)                       # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.6199, 0.6006, 0.6769, 0.6214, 0.6174, 0.612, 0.5616, 0.6276, 0.6654, 0.6466]
# BERT small #2 final score: 0.62

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.6365
#               precision    recall  f1-score   support
#
#   akadēmisks       0.95      0.84      0.89        25
#         citi       0.43      0.92      0.58        25
#  darba laiks       1.00      0.32      0.48        25
#    dokumenti       0.75      0.48      0.59        25
#
#     accuracy                           0.64       100
#    macro avg       0.78      0.64      0.64       100
# weighted avg       0.78      0.64      0.64       100
#
# [[21  3  0  1]
#  [ 0 23  0  2]
#  [ 0 16  8  1]
#  [ 1 12  0 12]]
# [[0.84 0.12 0.   0.04]
#  [0.   0.92 0.   0.08]
#  [0.   0.64 0.32 0.04]
#  [0.04 0.48 0.   0.48]]

# %% [markdown]
# <h2>Kombinētā Under & Over Sampling izvērtēšana</h2>

# %% [markdown]
# <h3>Oversampling apjoms = 100%</h3>

# %%
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 2*122
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)
undersampler = NearMiss()

model_scores = []
counter = 0
for i in range(10):
  X_res, y_res = undersampler.fit_resample(features, target)                      # Veicam Unersampling
  X_res, y_res = oversampler.fit_resample(X_res, y_res)                           # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.5281, 0.489, 0.5062, 0.5038, 0.4899, 0.4801, 0.4969, 0.5144, 0.5132, 0.5427]
# BERT small #2 final score: 0.51

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.5041
#               precision    recall  f1-score   support
#
#   akadēmisks       0.73      0.96      0.83        25
#         citi       1.00      0.04      0.08        25
#  darba laiks       0.71      0.48      0.57        25
#    dokumenti       0.41      0.80      0.54        25
#
#     accuracy                           0.57       100
#    macro avg       0.71      0.57      0.50       100
# weighted avg       0.71      0.57      0.50       100
#
# [[24  0  0  1]
#  [ 3  1  5 16]
#  [ 1  0 12 12]
#  [ 5  0  0 20]]
# [[0.96 0.   0.   0.04]
#  [0.12 0.04 0.2  0.64]
#  [0.04 0.   0.48 0.48]
#  [0.2  0.   0.   0.8 ]]

# %% [markdown]
# <h3>Oversampling apjoms = 200%</h3>

# %%
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 3*122
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)
undersampler = NearMiss()

model_scores = []
counter = 0
for i in range(10):
  X_res, y_res = undersampler.fit_resample(features, target)                      # Veicam Unersampling
  X_res, y_res = oversampler.fit_resample(X_res, y_res)                           # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.5179, 0.4787, 0.4985, 0.5271, 0.5551, 0.533, 0.521, 0.5125, 0.5372, 0.5273]
# BERT small #2 final score: 0.52

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.5641
#               precision    recall  f1-score   support
#
#   akadēmisks       0.77      0.96      0.86        25
#         citi       1.00      0.04      0.08        25
#  darba laiks       0.59      0.76      0.67        25
#    dokumenti       0.56      0.80      0.66        25
#
#     accuracy                           0.64       100
#    macro avg       0.73      0.64      0.56       100
# weighted avg       0.73      0.64      0.56       100
#
# [[24  0  0  1]
#  [ 1  1 12 11]
#  [ 2  0 19  4]
#  [ 4  0  1 20]]
# [[0.96 0.   0.   0.04]
#  [0.04 0.04 0.48 0.44]
#  [0.08 0.   0.76 0.16]
#  [0.16 0.   0.04 0.8 ]]

# %% [markdown]
# <h3>Oversampling apjoms = 300%</h3>

# %%
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import BorderlineSMOTE
from keras import layers, models
from sklearn.metrics import f1_score
print(X.shape, Y.shape)
print(features.shape, target.shape)
y_test = Y.to_numpy()

size = 4*122
thisdict = {
  1: size,
  3: size,
  2: size,
  0: size
}
oversampler = BorderlineSMOTE(sampling_strategy=thisdict)
undersampler = NearMiss()

model_scores = []
counter = 0
for i in range(10):
  X_res, y_res = undersampler.fit_resample(features, target)                      # Veicam Unersampling
  X_res, y_res = oversampler.fit_resample(X_res, y_res)                           # Veicam Oversampling

  ### Keras Sequential ###
  model = models.Sequential()
  model.add(layers.Dense(256, activation='relu', input_shape=(col_count,)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))
  model.compile(loss=['sparse_categorical_crossentropy'],
                optimizer='adam',
                metrics=['sparse_categorical_crossentropy'])
  history = model.fit(X_res, y_res,
                      batch_size=64,
                      epochs=5,
                      verbose=0)
  y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
  keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
  f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)              # Fiksējam f1 vidējo rezultātu
  counter = counter + 1
  model_scores.append(f1_avg)
  print('Completed iteration #',counter)
f1_final_score = round(np.mean(model_scores),2)
print('BERT small #2 scores:', model_scores)
print('BERT small #2 final score:',f1_final_score)
# Out:
# (100, 256) (100, 1)
# (23391, 256) (23391, 1)
# Completed iteration # 1
# Completed iteration # 2
# Completed iteration # 3
# Completed iteration # 4
# Completed iteration # 5
# Completed iteration # 6
# Completed iteration # 7
# Completed iteration # 8
# Completed iteration # 9
# Completed iteration # 10
# BERT small #2 scores: [0.504, 0.508, 0.5031, 0.5423, 0.5339, 0.5077, 0.4906, 0.5189, 0.5085, 0.514]
# BERT small #2 final score: 0.51

# %%
from sklearn.metrics import plot_confusion_matrix, f1_score, classification_report, confusion_matrix
y_pred = model.predict(X)                                                       # Prasam modelim paredzēt testa datiem kategorijas
keras_y_pred = transformResults(y_pred)                                         # Pārveidojam rezultātus, paņemot ticamāko klasi no varbūtībām
y_test = Y.to_numpy()
class_names = ['akadēmisks', 'citi', 'darba laiks', 'dokumenti']
naive_f1_avg = round(f1_score(y_test, keras_y_pred, average='macro'),4)               # Fiksējam Naive Bayes f1 vidējo rezultātu
print('Naive Bayes F1 score:', naive_f1_avg)
print(classification_report(y_test, keras_y_pred, target_names=class_names))
print(confusion_matrix(y_test, keras_y_pred, normalize=None))
print(confusion_matrix(y_test, keras_y_pred, normalize='true'))
# Out:
# Naive Bayes F1 score: 0.5049
#               precision    recall  f1-score   support
#
#   akadēmisks       0.79      0.92      0.85        25
#         citi       0.00      0.00      0.00        25
#  darba laiks       0.62      0.60      0.61        25
#    dokumenti       0.43      0.80      0.56        25
#
#     accuracy                           0.58       100
#    macro avg       0.46      0.58      0.50       100
# weighted avg       0.46      0.58      0.50       100
#
# [[23  0  0  2]
#  [ 1  0  8 16]
#  [ 1  0 15  9]
#  [ 4  0  1 20]]
# [[0.92 0.   0.   0.08]
#  [0.04 0.   0.32 0.64]
#  [0.04 0.   0.6  0.36]
#  [0.16 0.   0.04 0.8 ]]
